# %%
import pandas as pd

# %%
df_train = pd.read_csv(r'/home/rahul/Downloads/data-science-bowl-2019/split/xaa.csv',nrows=150000)
df_specs = pd.read_csv(r'/home/rahul/Downloads/data-science-bowl-2019/specs.csv')
df_train_labels = pd.read_csv(r'/home/rahul/Downloads/data-science-bowl-2019/train_labels.csv')

# %% [markdown]
# # Training dataset with JSON data under event_data

# %%
df_train.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# ...

# %% [markdown]
# # Event_id description

# %%
df_specs.head()
# Out:
#    event_id                                               info  \
# 0  2b9272f4  The end of system-initiated feedback (Correct)...
# 1  df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2  3babcb9b  The end of system-initiated instruction event ...
# 3  7f0836bf  The end of system-initiated instruction event ...
# 4  ab3136ba  The end of system-initiated instruction event ...
#
#                                                 args
# 0  [{"name":"game_time","type":"int","info":"mill...
# 1  [{"name":"game_time","type":"int","info":"mill...
# 2  [{"name":"game_time","type":"int","info":"mill...
# 3  [{"name":"game_time","type":"int","info":"mill...
# 4  [{"name":"game_time","type":"int","info":"mill...

# %% [markdown]
# # Accuracy Group with respect to game_session (either its Game/Activity/Clip etc) of a child (installation_id)

# %% [markdown]
# Number of childrens who have instlled the diffrent games

# %%
df_train_labels['installation_id'].count()
# Out:
# 17690

# %%
df_train_labels['installation_id'].value_counts(sort=True, ascending=False)
# Out:
# 08987c08    156
# f1c21eda    129
# 9f399a3a     78
# 8e44d2de     72
# 96979008     64
#            ...
# b1d58078      1
# c3e96fd6      1
# eca8c9af      1
# 844bb0b4      1
# 8185df72      1
# Name: installation_id, Length: 3614, dtype: int64

# %%
df_train_labels.head(20)
# Out:
#         game_session installation_id                         title  \
# 0   6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1   77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2   901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3   9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4   a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
# 5   197a373a77101924        0006c192  Cauldron Filler (Assessment)
# 6   957406a905d59afd        0006c192    Bird Measurer (Assessment)
# 7   b2297d292892745a        0006c192  Mushroom Sorter (Assessment)
# 8   ae691ec5ad5652cf        00129856    Bird Measurer (Assessment)
# 9   7b536271e99518f0        001d0ed0    Bird Measurer (Assessment)
# 10  8fdd5d389d0e272e        001d0ed0     Chest Sorter (Assessment)
# 11  9480b026e3e7d371        001d0ed0    Cart Balancer (Assessment)
# 12  c046a858e7c8bf03        001d0ed0  Mushroom Sorter (Assessment)
# ...

# %%
import json
#df_train.join(df_train['event_data'].apply(json.loads).apply(pd.Series))
type(df_train['event_data'])
# Out:
# pandas.core.series.Series

# %%
df_train['event_data']
# Out:
# 0                    {"event_code": 2000, "event_count": 1}
# 1                    {"event_code": 2000, "event_count": 1}
# 2         {"version":"1.0","event_count":1,"game_time":0...
# 3         {"description":"Let's build a sandcastle! Firs...
# 4         {"description":"Let's build a sandcastle! Firs...
#                                 ...
# 227113    {"crystal_id":"gem05","weight":4,"coordinates"...
# 227114    {"crystal_id":"gem06","weight":4,"coordinates"...
# 227115    {"crystal_id":"gem06","weight":4,"coordinates"...
# 227116    {"crystal_id":"gem04","weight":3,"coordinates"...
# 227117                                                  NaN
# Name: event_data, Length: 227118, dtype: object

# %% [markdown]
# # Extract event data and make it denormalized for easy undersatnding

# %%
import json
df_event = pd.io.json.json_normalize(df_train['event_data'].apply(json.loads)) ## works on windows
#Keeping the event_id and game_session as both are unique combo for a single observation
df_event_denom= pd.concat([df_train[['event_id','game_session']],df_event],axis=1)

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
df_event_denom.head(200)
# Out:
#      event_id      game_session  event_code  event_count version  game_time  \
# 0    27253bdc  45bb1e1b6b50c07b        2000            1     NaN        NaN
# 1    27253bdc  17eeb7f223665f53        2000            1     NaN        NaN
# 2    77261ab5  0848ef14a8dc6892        2000            1     1.0        0.0
# 3    b2dba42b  0848ef14a8dc6892        3010            2     NaN       53.0
# 4    1bb5fbdb  0848ef14a8dc6892        3110            3     NaN     6972.0
# 5    1325467d  0848ef14a8dc6892        4070            4     NaN     9991.0
# 6    1325467d  0848ef14a8dc6892        4070            5     NaN    10622.0
# 7    1325467d  0848ef14a8dc6892        4070            6     NaN    11255.0
# 8    1325467d  0848ef14a8dc6892        4070            7     NaN    11689.0
# 9    1325467d  0848ef14a8dc6892        4070            8     NaN    12272.0
# 10   1325467d  0848ef14a8dc6892        4070            9     NaN    12672.0
# ...

# %%
#136 + 2(event_id,game_session) features
df_event_denom.shape
# Out:
# (150000, 138)

# %%
df_event_denom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Columns: 138 entries, event_id to chests
# dtypes: float64(64), int64(2), object(72)
# memory usage: 157.9+ MB

# %%
df_event_denom[['event_id','game_session','event_code']].nunique()
# Out:
# event_id         357
# game_session    4254
# event_code        42
# dtype: int64

# %%
df_event_denom.describe()
# 66 Numaric features out of 136 (70 are object)
# Out:
#           event_code    event_count     game_time  total_duration  \
# count  150000.000000  150000.000000  1.474750e+05    26234.000000
# mean     3499.243200      89.057767  1.702579e+05     3813.213654
# std       684.736273     107.237643  8.499727e+05     3477.407643
# min      2000.000000       1.000000  0.000000e+00        0.000000
# 25%      3020.000000      24.000000  3.140650e+04     1666.000000
# 50%      4020.000000      56.000000  7.045700e+04     2933.000000
# 75%      4035.000000     112.000000  1.427365e+05     4933.000000
# max      5010.000000     975.000000  7.648688e+07    44733.000000
#
#            duration  coordinates.x  coordinates.y  coordinates.stage_width  \
# count  5.054600e+04   74694.000000   74694.000000             74694.000000
# mean   3.311680e+04     538.785886     395.154925              1061.946368
# std    7.153504e+05     291.498781     193.969595               212.974847
# ...

# %%
df_event_denom['exit_type'].value_counts()
# Out:
# game_completed    36
# Name: exit_type, dtype: int64

# %% [markdown]
# # Figuring out which Event_id belongs to which type/world/title

# %%
df_train.groupby(by='world').count()
# Out:
#               event_id  game_session  timestamp  event_data  installation_id  \
# world
# CRYSTALCAVES     44389         44389      44389       44389            44389
# MAGMAPEAK        64886         64886      64886       64886            64886
# NONE               315           315        315         315              315
# TREETOPCITY      40410         40410      40410       40410            40410
#
#               event_count  event_code  game_time  title   type
# world
# CRYSTALCAVES        44389       44389      44389  44389  44389
# MAGMAPEAK           64886       64886      64886  64886  64886
# NONE                  315         315        315    315    315
# TREETOPCITY         40410       40410      40410  40410  40410

# %%
df_train.groupby(by=['type','world','title'])['type','world','title','event_id'].nunique()
# Out:
#                                                        type  world  title  \
# type       world        title
# Activity   CRYSTALCAVES Chicken Balancer (Activity)       1      1      1
#                         Egg Dropper (Activity)            1      1      1
#            MAGMAPEAK    Bottle Filler (Activity)          1      1      1
#                         Sandcastle Builder (Activity)     1      1      1
#                         Watering Hole (Activity)          1      1      1
#            TREETOPCITY  Bug Measurer (Activity)           1      1      1
#                         Fireworks (Activity)              1      1      1
#                         Flower Waterer (Activity)         1      1      1
# Assessment CRYSTALCAVES Cart Balancer (Assessment)        1      1      1
#                         Chest Sorter (Assessment)         1      1      1
#            MAGMAPEAK    Cauldron Filler (Assessment)      1      1      1
# ...

# %%
df_train.groupby(by=['world','type','title'])['world','type','title','event_id','event_code'].nunique()
# Out:
#                                                        world  type  title  \
# world        type       title
# CRYSTALCAVES Activity   Chicken Balancer (Activity)        1     1      1
#                         Egg Dropper (Activity)             1     1      1
#              Assessment Cart Balancer (Assessment)         1     1      1
#                         Chest Sorter (Assessment)          1     1      1
#              Clip       Balancing Act                      1     1      1
#                         Crystal Caves - Level 1            1     1      1
#                         Crystal Caves - Level 2            1     1      1
#                         Crystal Caves - Level 3            1     1      1
#                         Heavy, Heavier, Heaviest           1     1      1
#                         Honey Cake                         1     1      1
#                         Lifting Heavy Things               1     1      1
# ...

# %%
df_train.groupby(by=['world','type','title','event_id'])[['game_time']].sum().reset_index()
# Out:
#             world        type                          title  event_id  \
# 0    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  46cd75b4
# 1    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  499edb7c
# 2    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  4bb2f698
# 3    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  56bcd38d
# 4    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  756e5507
# 5    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  84b0e0c8
# 6    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  85d1b0de
# 7    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  cdd22e43
# 8    CRYSTALCAVES    Activity    Chicken Balancer (Activity)  ea321fb1
# 9    CRYSTALCAVES    Activity         Egg Dropper (Activity)  461eace6
# 10   CRYSTALCAVES    Activity         Egg Dropper (Activity)  4c2ec19f
# 11   CRYSTALCAVES    Activity         Egg Dropper (Activity)  736f9581
# ...

# %% [markdown]
# # Removing duplicate combinations so that we can distinguish unique combination of event_id -->title --> world-->type

# %%
#gdf1=df_train.groupby(by=['type','world','title'])[['type','world','title','event_id','game_time']]

# %%
#type(gdf1)

# %%
#coredf=gdf1.apply(lambda inputdf: inputdf)

# %%
#type(coredf)

# %%
#coredf=coredf.drop_duplicates(subset=['type','world','title','event_id','game_time'],keep='first')

# %%
#coredf.shape

# %%
df_t1 = df_train.groupby(by=['world','type','title','event_id','event_code'])[['game_time']].mean().reset_index()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_t1.shape
# Out:
# (376, 6)

# %%
df_t1[['event_id','event_code']].nunique()
# Out:
# event_id      357
# event_code     42
# dtype: int64

# %%
#g=sns.catplot(x="event_code", y="game_time", kind="box", data=df_t1[df_t1['game_time'] > 0]);
#g.fig.set_size_inches(15,10)
g=sns.FacetGrid(df_t1[df_t1['game_time'] > 0], row="game_time", col="event_code")
g.fig.set_size_inches(15,10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-d0a182fb9346> in <module>
#       1 #g=sns.catplot(x="event_code", y="game_time", kind="box", data=df_t1[df_t1['game_time'] > 0]);
#       2 #g.fig.set_size_inches(15,10)
# ----> 3 g=sns.FacetGrid(df_t1[df_t1['game_time'] > 0], row="game_time", col="event_code")
#       4 g.fig.set_size_inches(15,10)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     309                     warnings.warn(msg.format(MPL_GRIDSPEC_VERSION))
#     310
# --> 311             fig, axes = plt.subplots(nrow, ncol, **kwargs)
#     312             self.axes = axes
#     313
#
# ...

# %%
df_t1
# Out:
#             world        type                        title  event_id  \
# 0    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  46cd75b4
# 1    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  499edb7c
# 2    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  4bb2f698
# 3    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  56bcd38d
# 4    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  756e5507
# 5    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  84b0e0c8
# 6    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  85d1b0de
# 7    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  cdd22e43
# 8    CRYSTALCAVES    Activity  Chicken Balancer (Activity)  ea321fb1
# 9    CRYSTALCAVES    Activity       Egg Dropper (Activity)  461eace6
# 10   CRYSTALCAVES    Activity       Egg Dropper (Activity)  4c2ec19f
# 11   CRYSTALCAVES    Activity       Egg Dropper (Activity)  736f9581
# 12   CRYSTALCAVES    Activity       Egg Dropper (Activity)  7ab78247
# ...
